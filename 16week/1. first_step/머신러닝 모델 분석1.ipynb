# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
data.shape
# Out:
# (6819, 96)

# %%
data_corr = data.corr()
data_corr
# Out:
#                                                     Bankrupt?  \
# Bankrupt?                                            1.000000
#  ROA(C) before interest and depreciation before...  -0.260807
#  ROA(A) before interest and % after tax             -0.282941
#  ROA(B) before interest and depreciation after tax  -0.273051
#  Operating Gross Margin                             -0.100043
# ...                                                       ...
#  Liability to Equity                                 0.166812
#  Degree of Financial Leverage (DFL)                  0.010508
#  Interest Coverage Ratio (Interest expense to E...  -0.005509
#  Net Income Flag                                          NaN
#  Equity to Liability                                -0.083048
#
#                                                      ROA(C) before interest and depreciation before interest  \
# Bankrupt?                                                                                   -0.260807
# ...

# %%
data1 = data.iloc[:,:20]
data2 = pd.concat([data.iloc[:,0], data.iloc[:,20:39]], axis=1)
data3 = pd.concat([data.iloc[:,0], data.iloc[:,39:58]], axis=1)
data4 = pd.concat([data.iloc[:,0], data.iloc[:,58:77]], axis=1)
data5 = pd.concat([data.iloc[:,0], data.iloc[:,77:96]], axis=1)

# %%
data1.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
data[' Net Income Flag'].value_counts()
# Out:
# 1    6819
# Name:  Net Income Flag, dtype: int64

# %%
plt.figure(figsize=(13,13))
data1_corr = data1.corr()
sns.heatmap(data1_corr, cmap='Blues', annot=True, cbar=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(13,13))
data2corr = data2.corr()
sns.heatmap(data2corr, cmap='Blues', annot=True, cbar=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(13,13))
data3corr = data3.corr()
sns.heatmap(data3corr, cmap='Blues', annot=True, cbar=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(13,13))
data4corr = data4.corr()
sns.heatmap(data4corr, cmap='Blues', annot=True, cbar=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(13,13))
data5corr = data5.corr()
sns.heatmap(data5corr, cmap='Blues', annot=True, cbar=False)
# Out:
# <AxesSubplot:>

# %%
data['Bankrupt?'].value_counts() #불균형 데이터
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
data.isnull().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
#over sampling - SMOTE

from imblearn.over_sampling import *

X = data.iloc[:,1:]
y = data.iloc[:,0]

X_res, y_res = SMOTE(random_state=50).fit_resample(X,y)

print('the shape of X_res: ', X_res.shape)
print('the shape of y_res: ', y_res.shape)

print('counts of label 1: ', sum(y_res==1))
print('counts of label 0: ', sum(y_res==0))
# Out:
# the shape of X_res:  (13198, 95)
# the shape of y_res:  (13198,)
# counts of label 1:  6599
# counts of label 0:  6599

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.3, random_state=1)

# %%
from sklearn import neighbors  #KNN
from sklearn.svm import SVC    #SVC
from sklearn.linear_model import LogisticRegression  #LogisticRegression
from sklearn.tree import DecisionTreeClassifier  #DecisionTree
from sklearn.naive_bayes import GaussianNB   #가우시안
from sklearn.ensemble import RandomForestClassifier #RandomForest
from sklearn.ensemble import AdaBoostClassifier   #Adaboost
from sklearn.ensemble import GradientBoostingClassifier   #GradientBoost
from xgboost import XGBClassifier   #XGBoost
from lightgbm import LGBMClassifier  #Light GBM
from sklearn.metrics import accuracy_score
import warnings

warnings.filterwarnings('ignore')

knn = neighbors.KNeighborsClassifier()
lr = LogisticRegression()
tree = DecisionTreeClassifier()
GNB = GaussianNB()
rf = RandomForestClassifier()
ada = AdaBoostClassifier()
gb = GradientBoostingClassifier()
xgb = XGBClassifier()
lgbm = LGBMClassifier()

for model in [knn, lr, tree, GNB, rf, ada, gb, xgb, lgbm]:
    model.fit(X_train, y_train)
    pred_model = model.predict(X_test)
    accuracy = accuracy_score(y_test, pred_model)
    
    print('{0}: {1: .4f}'.format(model, accuracy))
# Out:
# KNeighborsClassifier():  0.9025
# LogisticRegression():  0.6078
# DecisionTreeClassifier():  0.9530
# GaussianNB():  0.5073
# RandomForestClassifier():  0.9770
# AdaBoostClassifier():  0.9359
# GradientBoostingClassifier():  0.9583
# [01:15:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
# ...

# %%
#별 다른 데이터 전처리를 하지 않고도 oversampling-SMOTE 만 적용시킨 결과, LGBM에서 98%가 나옴.
#Logistic, GaussianNB가 낮게나온건 다중공선성 때문일듯..

# %%
#over sampling한 데이터로 전처리 해보기 

#차원축소(랜덤포레스트로 feature 선택)-> 이상치 제거  모델 적합

#1) 렌덤포레스트

plt.figure(figsize=(8, 10))
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf_importances_value = rf.feature_importances_
rf_importances = pd.Series(rf_importances_value, index=X_train.columns)
rf_top = rf_importances.sort_values(ascending=False)[:30]
sns.barplot(x=rf_top, y=rf_top.index)
plt.show()

sel_X = X_res[rf_top[rf_top > 0.01].index]

# %%
print(sel_X.shape)
print(y_res.shape)

#23개로 feauture 줄임
# Out:
# (13198, 30)
# (13198,)

# %%
def outlier(df=None, column=None):
    quantile_25 = np.percentile(df[column].values, 25)
    quantile_75 = np.percentile(df[column].values, 75)
    
    IQR = quantile_75 - quantile_25
    IQR_weight = IQR*1.5
    
    lowest = quantile_25 - IQR_weight
    highest = quantile_75 + IQR_weight
    
    outlier_idx = df[column][(df[column] < lowest) | (df[column] > highest)].index
    
    return outlier_idx

# %%
for i in sel_X.columns:
    if len(outlier(df=sel_X, column=i)) > 0:
        print('칼럼이름: ', i)
        print(outlier(df=data, column=i))
        
#outlier제거는 하면 안될것같음..
# Out:
# 칼럼이름:   Continuous interest rate (after tax)
# Int64Index([   0,    2,    3,    5,    6,   25,   54,   56,   92,  119,
#             ...
#             6732, 6749, 6752, 6756, 6759, 6761, 6772, 6788, 6789, 6818],
#            dtype='int64', length=806)
# 칼럼이름:   Net Income to Total Assets
# Int64Index([   0,    3,    5,    6,   29,   56,   57,  119,  123,  232,
#             ...
#             6641, 6642, 6668, 6687, 6700, 6749, 6751, 6756, 6761, 6789],
#            dtype='int64', length=561)
# 칼럼이름:   Persistent EPS in the Last Four Seasons
# Int64Index([   0,    5,    6,   29,   56,   57,  177,  232,  235,  368,
#             ...
#             6685, 6687, 6689, 6731, 6751, 6753, 6764, 6781, 6789, 6795],
#            dtype='int64', length=508)
# 칼럼이름:   Retained Earnings to Total Assets
# Int64Index([   0,    2,    3,    5,   29,   30,   31,   56,   58,   82,
#             ...
#             6700, 6707, 6733, 6745, 6751, 6756, 6759, 6764, 6789, 6809],
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(sel_X, y_res, test_size = 0.3, random_state=1)

# %%
from sklearn import neighbors  #KNN
from sklearn.svm import SVC    #SVC
from sklearn.linear_model import LogisticRegression  #LogisticRegression
from sklearn.tree import DecisionTreeClassifier  #DecisionTree
from sklearn.naive_bayes import GaussianNB   #가우시안
from sklearn.ensemble import RandomForestClassifier #RandomForest
from sklearn.ensemble import AdaBoostClassifier   #Adaboost
from sklearn.ensemble import GradientBoostingClassifier   #GradientBoost
from xgboost import XGBClassifier   #XGBoost
from lightgbm import LGBMClassifier  #Light GBM
from sklearn.metrics import accuracy_score
import warnings

warnings.filterwarnings('ignore')

knn = neighbors.KNeighborsClassifier()
lr = LogisticRegression()
tree = DecisionTreeClassifier()
GNB = GaussianNB()
rf = RandomForestClassifier()
ada = AdaBoostClassifier()
gb = GradientBoostingClassifier()
xgb = XGBClassifier()
lgbm = LGBMClassifier()

for model in [knn, lr, tree, GNB, rf, ada, gb, xgb, lgbm]:
    model.fit(X_train, y_train)
    pred_model = model.predict(X_test)
    accuracy = accuracy_score(y_test, pred_model)
    
    print('{0}: {1: .4f}'.format(model, accuracy))
# Out:
# KNeighborsClassifier():  0.7313
# LogisticRegression():  0.3705
# DecisionTreeClassifier():  0.9477
# GaussianNB():  0.5086
# RandomForestClassifier():  0.9697
# AdaBoostClassifier():  0.9152
# GradientBoostingClassifier():  0.9434
# [02:54:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
# ...

# %%
#피쳐 개수 선택 다양하게 해봤는데 원래 것보다 높게 나오지 X
#높게 나온 rf, XGB, LGBM 으로 GridSearch 실행

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.3, random_state=1)

# %%
#1) Randomforest

from sklearn.model_selection import GridSearchCV

params = {'n_estimators':[100],
         'max_depth':[12,16],
         'min_samples_leaf':[1,2,4],
         'min_samples_split':[2,4,8]}

rf = RandomForestClassifier()
grid_rf = GridSearchCV(rf, param_grid=params, cv=2)
grid_rf.fit(X_train, y_train)

print(grid_rf.best_params_)
print(grid_rf.best_score_)
# Out:
# {'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.9663347044814895

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

pred_rf = grid_rf.predict(X_test)
accuracy = accuracy_score(y_test, pred_rf)
precision = precision_score(y_test, pred_rf)
recall = recall_score(y_test, pred_rf)
f1 = f1_score(y_test, pred_rf)
                          
print('정확도: {0: .4f}, 정밀도: {1: .4f}, 재현율: {2: .4f}, f1 score: {3: .4f} '.format(accuracy, precision, recall, f1))
# Out:
# 정확도:  0.9742, 정밀도:  0.9541, 재현율:  0.9959, f1 score:  0.9746

# %%
#2) XGBoost

params = {'n_estimators':[100, 500],
         'learning_rate':[0.05,0.1, 0.3],
         'max_depth':[3,4,6]}

xgb = XGBClassifier()
grid_xgb = GridSearchCV(xgb, param_grid=params, cv=2)
grid_xgb.fit(X_train, y_train)

print(grid_xgb.best_params_)
print(grid_xgb.best_score_)
# Out:
# [04:12:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:12:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:12:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
pred_xgb = grid_xgb.predict(X_test)
accuracy = accuracy_score(y_test, pred_xgb)
precision = precision_score(y_test, pred_xgb)
recall = recall_score(y_test, pred_xgb)
f1 = f1_score(y_test, pred_xgb)
                          
print('정확도: {0: .4f}, 정밀도: {1: .4f}, 재현율: {2: .4f}, f1 score: {3: .4f} '.format(accuracy, precision, recall, f1))
# Out:
# 정확도:  0.9869, 정밀도:  0.9751, 재현율:  0.9990, f1 score:  0.9869

# %%
grid_xgb.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 500}

# %%
#2) LGBM

grid_lgbm = LGBMClassifier(learning_rate=0.1, max_depth=4, n_estimators=500)
grid_lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(max_depth=4, n_estimators=500)

# %%
pred_lgbm = grid_lgbm.predict(X_test)
accuracy = accuracy_score(y_test, pred_lgbm)
precision = precision_score(y_test, pred_lgbm)
recall = recall_score(y_test, pred_lgbm)
f1 = f1_score(y_test, pred_lgbm)
      
print('정확도: {0: .4f}, 정밀도: {1: .4f}, 재현율: {2: .4f}, f1 score: {3: .4f} '.format(accuracy, precision, recall, f1))
# Out:
# 정확도:  0.9864, 정밀도:  0.9737, 재현율:  0.9995, f1 score:  0.9864

# %%
#보팅 - soft

from sklearn.ensemble import VotingClassifier

vo_soft = VotingClassifier(estimators=[('rf',grid_rf), ('xgb',grid_xgb), ('lgbm',grid_lgbm)], voting='soft')
vo_soft.fit(X_train,y_train)

pred_s = vo_soft.predict(X_test)
accuracy = accuracy_score(y_test, pred_s)
precision = precision_score(y_test, pred_s)
recall = recall_score(y_test, pred_s)
f1 = f1_score(y_test, pred_s)
      
print('정확도: {0: .4f}, 정밀도: {1: .4f}, 재현율: {2: .4f}, f1 score: {3: .4f} '.format(accuracy, precision, recall, f1))
# Out:
# [04:38:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:38:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:38:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
#보팅 - hard

from sklearn.ensemble import VotingClassifier

vo_hard = VotingClassifier(estimators=[('rf',grid_rf), ('xgb',grid_xgb), ('lgbm',grid_lgbm)], voting='hard')
vo_hard.fit(X_train,y_train)

pred_h = vo_hard.predict(X_test)
accuracy = accuracy_score(y_test, pred_h)
precision = precision_score(y_test, pred_h)
recall = recall_score(y_test, pred_h)
f1 = f1_score(y_test, pred_h)
      
print('정확도: {0: .4f}, 정밀도: {1: .4f}, 재현율: {2: .4f}, f1 score: {3: .4f} '.format(accuracy, precision, recall, f1))
# Out:
# [04:46:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:46:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [04:46:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...
