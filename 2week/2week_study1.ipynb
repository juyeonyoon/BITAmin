# %% [markdown]
# # 01.matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **막대그래프**

# %%
labels = ['Kor', 'Maths', 'Eng', 'Sci']
scores = [80,90,75,100]
plt.bar(labels, scores) #가로형 막대그래프
plt.show()

# %%
plt.barh(labels, scores) #세로형 막대그래프
plt.show()

# %%
plt.bar(labels, scores, align = 'center', color = 'green', alpha = 0.5)

#x축 이름 설정, y축 눈금 설정
plt.xticks(labels, fontsize = 15, rotation = 30) #rotation: 기울기
plt.yticks(fontsize = 15, rotation = 30)

#label 및 title 설정(x는 Subject, y는 Score)
plt.xlabel('Subject', fontsize = 15)
plt.ylabel('Score', fontsize = 15)
plt.title('Scores for midterm exam', fontsize = 20)

plt.show()

# %%
#가로형 막대그래프
plt.barh(labels, scores, align = 'center', color = 'red', alpha = 0.5)

plt.xticks(fontsize = 15, rotation = 30)
plt.yticks(labels, fontsize = 15, rotation = 30)

plt.xlabel('Score', fontsize = 15)
plt.ylabel('Subject', fontsize = 15)
plt.title('Scores for midterm exam', fontsize = 20)

plt.show()

# %%
data = [['A', 90, 100, 80], ['B', 70, 90, 85], ['C', 100, 95, 75], ['D', 80, 90,95]]
df = pd.DataFrame(data, columns = ['Name','Kor','Maths','Eng'])
df
# Out:
#   Name  Kor  Maths  Eng
# 0    A   90    100   80
# 1    B   70     90   85
# 2    C  100     95   75
# 3    D   80     90   95

# %%
df.plot(x = 'Name', y = ['Kor','Maths','Eng'], kind = 'bar', figsize = (9,8)) #figsize: 전체 크기
plt.show()

# %%
df.plot(x = 'Name', y = ['Kor','Maths','Eng'], kind = 'barh', figsize = (9,8))
plt.show()

# %%
employees = ['Rudra','Alok','Prince','Nayan','Reman']
earnings = {'January':[10,20,15,18,14], 'Faburary':[20,13,10,18,15], 'March':[20,20,10,15,18]}
df = pd.DataFrame(earnings, index = employees)
df
# Out:
#         January  Faburary  March
# Rudra        10        20     20
# Alok         20        13     20
# Prince       15        10     10
# Nayan        18        18     15
# Reman        14        15     18

# %%
#stacked = True: 누적 막대그래프 default 값은 stacked = False
df.plot(kind = 'bar', stacked = True, figsize = (10,8))
plt.legend(loc = 'lower left') #범례 표시 
plt.show()

# %% [markdown]
# **파이 차트**

# %%
labels = ['Dog', 'Cat', 'Fish', 'Others']
sizes = [45, 30, 15, 10]

plt.pie(sizes)
plt.show()

# %%
#labels = <> : 파이차트 밖에 라벨 표시
#autopct = <> : 파이차트 안에 수치 표현 ex) %.1f/ %.1f%% / %d%% 
#explode = <> : 부채꼴이 파이 차트의 중심에서 벗어나는 정도를 설명 
#shadow = True/False : 그림자 표시
#startangle = <> : 부채꼴이 그려지는 시작 각도를 설정(시계 반대방향)
plt.pie(sizes, labels=labels, autopct='%1.1f%%', explode=(0.2,0,0,0), shadow=True, startangle=90)
plt.title('Animals', fontsize = 15)
plt.show()

# %%
#colors = <> : 색깔 표시
#wedgerprops = <> : 부채꼴 영역의 스타일 결정
#counterclock = True/False : False로 설정하면 시계방향순서로 부채꼴 영역 표시
ratio = [34, 32,16,18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['red', 'yellow', 'green', 'purple']
wedgeprops = {'width': 0.7, 'edgecolor': 'w', 'linewidth':5}

plt.pie(ratio, labels=labels, autopct='%1.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff5fe2e6ad0>,
#   <matplotlib.patches.Wedge at 0x7ff5fe2f1190>,
#   <matplotlib.patches.Wedge at 0x7ff5fe2f1a10>,
#   <matplotlib.patches.Wedge at 0x7ff5fe2fc350>],
#  [Text(-1.0413141901100615, -0.3544922530541775, 'Apple'),
#   Text(0.19101299543362346, 1.0832885283134288, 'Banana'),
#   Text(1.0931447152094993, -0.12261578858182408, 'Melon'),
#   Text(0.4191774368377346, -1.017000627554451, 'Grapes')],
#  [Text(-0.5679895582418516, -0.19335941075682406, '34.0%'),
#   Text(0.10418890660015824, 0.5908846518073247, '32.0%'),
#   Text(0.5962607537506359, -0.06688133922644948, '16.0%'),
#   Text(0.22864223827512792, -0.5547276150297005, '18.0%')])

# %% [markdown]
# **선 그래프**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(0,10, 0.1)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
year = [2015, 2016, 2017, 2018, 2019]
goals = [52, 59, 54, 51, 50]
plt.plot(year, goals, color = 'green', marker = 'o', linestyle = 'solid')

plt.title('Number of goals in 5 years')
plt.xlabel('Year')
plt.ylabel('Number of goals')

plt.xticks(rotation = 50)
plt.show()

# %%
year = [2015, 2016, 2017, 2018, 2019]
goals = [52, 59, 54, 51, 50]
plt.plot(year, goals, color = 'green', marker = 'o', linestyle = 'solid')

plt.title('Number of goals in 5 years')
plt.xlabel('Year')
plt.ylabel('Number of goals')


#xlim, ylim: 각 축의 최솟값, 최댓값 지정; 제한 범위 지정
plt.xticks(rotation = 50)
plt.ylim(40,60)
plt.xlim(2014,2020)
plt.show()

# %%
#선 그래프 2개 이상 그리기 
year = [2015, 2016, 2017, 2018, 2019]
goals = [52, 59, 54, 51, 50]
goals2 = [57, 55, 53, 49, 52]
plt.plot(year, goals, color = 'green', marker = 'o', linestyle = 'solid')
plt.plot(year, goals2, color = 'blue', marker = 'o', linestyle = 'solid')

plt.title('Number of goals in 5 years')
plt.xlabel('Year')
plt.ylabel('Number of goals')

plt.xticks(rotation = 50)
plt.show()

# %%
year = [2015, 2016, 2017, 2018, 2019]
goals = [52, 59, 54, 51, 50]
goals2 = [57, 55, 53, 49, 52]

#표 안에 label = <> : 범례 표시
plt.plot(year, goals, color = 'green', marker = 'o', linestyle = 'solid', label = ('messi'))
plt.plot(year, goals2, color = 'blue', marker = 'o', linestyle = 'solid', label = ('honaldo'))

plt.legend(loc = 'upper right') #범례 위치

plt.title('Number of goals in 5 years')
plt.xlabel('Year')
plt.ylabel('Number of goals')

plt.xticks(rotation = 50)
plt.show()

# %%
#linestyle = <> : <> = solid, dotted, dashed 비교 

year = [2015, 2016, 2017, 2018, 2019]
goals = [52, 59, 54, 51, 50]
goals2 = [57, 55, 53, 49, 52]
plt.plot(year, goals, color = 'green', marker = 'o', linestyle = 'dotted', label = ('messi'))
plt.plot(year, goals2, color = 'blue', marker = 'o', linestyle = 'dashed', label = ('honaldo'))

plt.legend(loc = 'upper right')

plt.title('Number of goals in 5 years')
plt.xlabel('Year')
plt.ylabel('Number of goals')

plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# **히스토그램**

# %%
N = 10000
x = np.random.randn(N)

#bins = <> : 몇 개의 영역으로 나눌지 결정
plt.hist(x, bins = 30)
plt.show()

# %%
#density = True/False : True일 때, 확률밀도를 형성시키기 위해 정규화, 히스토그램 값들의 면적 값은 1이 됨
#cumulative = True : 누적분포
plt.hist(x, bins = 30, density=True, cumulative=True)
plt.yticks(fontsize = 15)

plt.show()

# %%
plt.hist(x, bins=30, color='green', alpha=0.5)
plt.hist(x+5, bins=60, color='orange',alpha=0.5)

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.legend(['histogram1','histogram2'], fontsize=15)
plt.show()

# %% [markdown]
# **박스플롯**
# - 5개의 요약통계량(최소값, 1분위수, 중앙값, 3분위수, 최대값) 제공
# - 분포의 대칭성, 이상치 쉽게 파악 가능

# %%
spread = np.random.rand(50)*100
center = np.ones(25)*50
flier_high = np.random.rand(10)*100+100
flier_low = np.random.rand(10)*-100
data = np.concatenate((spread, center, flier_high, flier_low))

plt.boxplot(data)
plt.show()

# %%
#vert = True/False : False일 때 verticle이 아닌 horizontal, 즉 가로
plt.boxplot(data, vert = False)
plt.show()

# %%
spread = np.random.rand(50)*100
center1 = np.ones(25)*50
center2 = np.ones(25)*50
flier_high = np.random.rand(10)*100+100
flier_low = np.random.rand(10)*-100
data1 = np.concatenate((spread, center1, flier_high, flier_low))
data2 = np.concatenate((spread, center2, flier_high, flier_low))
data = [data1, data2, data2[::5]]

plt.boxplot(data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **산점도**
# - 주로 서로 다른 연속형 변수의 관계 표현에 쓰임
# - 변수들의 관계, 패턴의 유무 파악이 목적

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x,y)
plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# c = <> : color 설정
# s = <> : 점의 size 설정
# alpha = <> : 투명도 설정
plt.title('correlation of total_bill and tip', fontsize = 15)
plt.scatter(x=tips['total_bill'], y = tips['tip'], c = 'coral', s = 10, alpha = 0.7)
plt.show()
