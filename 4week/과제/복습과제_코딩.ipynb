# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Label Encoding
# embark_town 변수를 레이블 인코딩하고,  <p>
# 레이블 인코딩한 값을 기존 데이터 프레임에 'embark_town_labels'라는 열로 추가해보세요.<p>

# %%
from sklearn.preprocessing import LabelEncoder
titanic = sns.load_dataset('titanic')

# %%
encoder = LabelEncoder()
embark_town_labels = encoder.fit_transform(titanic['embark_town'])
titanic['embark_town_labels'] = embark_town_labels
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  embark_town_labels
# 0    man        True  NaN  Southampton    no  False                   2
# 1  woman       False    C    Cherbourg   yes  False                   0
# 2  woman       False  NaN  Southampton   yes   True                   2
# 3  woman       False    C  Southampton   yes  False                   2
# 4    man        True  NaN  Southampton    no   True                   2

# %% [markdown]
# ### 2. 결측값/중복값 처리
# 타민은 한국환경공단에서 발표한 미세먼지 관련 자료를 분석하려고 데이터를 다운로드받았습니다. <p>
# 하지만 데이터에 결측값이 많아 이를 우선 조정하려고 합니다. <p>
#     타민과 함께 데이터를 처리해주세요! ('finedust.csv' 파일을 활용하세요)

# %% [markdown]
# #### 2.1.
# 파일을 불러와 컬럼 별 결측치 개수를 구하세요. <p>
# (이 파일은 공공기관 파일로, 인코딩이 utf-8이 아닌 cp949로 되어있습니다! <p>
#     read_csv 사용 시 오류가 발생하면 pd.read_csv('경로\\finedust.csv', engine='python')으로 불러와주세요! <p>
#         기타 문제 발생 시 바로 문의주세요!)

# %%
data = pd.read_csv('finedust.csv',encoding = 'cp949')
data.isnull().sum()
# Out:
# 측정일자            3
# 측정시간            8
# 지역              9
# 지역명             9
# 도로명           194
# 시작점           151
# 종점             63
# 기온             12
# 습도             32
# 재비산먼지 평균농도      4
# 오염범례           27
# dtype: int64

# %% [markdown]
# #### 2.2
# 타민은 '분석할만한 데이터가 6개 미만인 데이터는 제외해도 좋을 것 같은데?'라며 해당 데이터를 삭제하려 합니다.<p>
# 적합한 코드를 알려주세요. (tip: dropna, tresh 활용)

# %%
data.dropna(thresh = 6)
# Out:
#            측정일자   측정시간   지역  지역명    도로명                     시작점  \
# 0    2021-07-01   9:44   서울  구로구    부일로     서울특별시 구로구 궁동 197-10
# 1    2021-07-01  10:04   서울  구로구   서해안로     서울특별시 구로구 항동 211-22
# 2    2021-07-01  10:28   서울  구로구    중앙로      서울특별시 구로구 고척동 63-5
# 3    2021-07-01  10:35   서울  구로구    고척로     서울특별시 구로구 고척동 186-4
# 4    2021-07-01  11:04   서울  구로구    오리로          서울특별시 구로구 궁동 5
# 5    2021-07-01  11:49   서울  구로구    금오로      경기도 광명시 옥길동 667-21
# 6    2021-07-01  11:57   서울  구로구    천왕로     서울특별시 구로구 천왕동 14-44
# 7    2021-07-01  12:09   서울  구로구    개봉로     서울특별시 구로구 개봉동 372-1
# 8    2021-07-01  12:23   서울  구로구    공원로   서울특별시 구로구 신도림동 422-10
# 9    2021-07-01  12:30   서울  NaN    NaN    서울특별시 구로구 구로동 136-14
# 10   2021-07-01  12:41   서울  구로구   신도림로    서울특별시 구로구 신도림동 397-3
# 11   2021-07-01  12:51   서울  구로구    새말로       서울특별시 구로구 구로동 1-4
# 12   2021-07-01  13:02   서울  구로구   구로동로   서울특별시 구로구 구로동 496-119
# 13   2021-07-01  13:15   서울  구로구   디지털로                     NaN
# 14   2021-07-01  13:24   서울  구로구    도림로                     NaN
# 15   2021-07-01  13:37   서울  구로구   가마산로                     NaN
# 16   2021-07-01  13:49   서울  구로구    벚꽃로                     NaN
# 18   2021-07-01    NaN  NaN  NaN   경원대로                     NaN
# 19   2021-07-01    NaN  NaN  NaN    장제로                     NaN
# 20   2021-07-01  10:25   인천  부평구   부평대로                     NaN
# 21   2021-07-01  10:45   인천  부평구    부일로                     NaN
# 22   2021-07-01  10:49   인천  부평구    대정로                     NaN
# 23   2021-07-01  10:55   인천  부평구    부흥로                     NaN
# 24   2021-07-01  11:05   인천  부평구    부개로                     NaN
# 25   2021-07-01  11:09   인천  부평구    길주로                     NaN
# 26   2021-07-01  11:20   인천  부평구    원적로                     NaN
# 27   2021-07-01  11:33   인천  부평구   주부토로                     NaN
# 28   2021-07-01    NaN  NaN  NaN    굴포로                     NaN
# 29   2021-07-01  12:03   인천  부평구   부평북로                     NaN
# 30   2021-07-01  10:01   서울  금천구    문성로                     NaN
# ..          ...    ...  ...  ...    ...                     ...
# 270  2021-07-07  11:26   경기  부천시    NaN          경기도 부천시 내동 400
# 271  2021-07-07  11:40   경기  부천시    NaN          경기도 부천시 중동 881
# 272  2021-07-07  11:55   경기  부천시    NaN       경기도 부천시 삼정동 366-3
# 273  2021-07-07  12:09   경기  부천시    NaN          경기도 부천시 상동 482
# 274  2021-07-07  12:25   경기  부천시    NaN         경기도 부천시 오정동 227
# 275  2021-07-07  12:37   경기  부천시    NaN       경기도 부천시 삼정동 366-3
# 276  2021-07-07  12:45   경기  부천시    NaN          경기도 부천시 내동 395
# 277  2021-07-07  14:07   경기  부천시    NaN         경기도 부천시 송내동 471
# 278  2021-07-07  14:39   경기  부천시    NaN        서울특별시 구로구 온수동 56
# 279  2021-07-07  10:37   경기  화성시    NaN     경기도 화성시 향남읍 발안리 293
# 280  2021-07-07  10:45   경기  화성시    NaN   경기도 화성시 팔탄면 가재리 539-3
# 281  2021-07-07  11:01   경기  화성시    NaN    경기도 화성시 향남읍 평리 76-62
# 282  2021-07-07  11:10   경기  화성시    NaN     경기도 화성시 향남읍 행정리 577
# 283  2021-07-07  11:15   경기  화성시    NaN   경기도 화성시 향남읍 행정리 582-1
# 284  2021-07-07  11:20   경기  화성시    NaN     경기도 화성시 향남읍 행정리 553
# 285  2021-07-07  11:36   경기  화성시    NaN    경기도 화성시 봉담읍 유리 137-2
# 286  2021-07-07  11:55   경기  화성시    NaN  경기도 화성시 봉담읍 동화리 425-57
# 287  2021-07-07  12:10   경기  화성시    NaN     경기도 화성시 봉담읍 동화리 640
# 288  2021-07-07  12:17   경기  화성시    NaN                     NaN
# 289  2021-07-07  12:42   경기  화성시    NaN                     NaN
# 290  2021-07-07  12:47   경기  화성시    NaN                     NaN
# 291  2021-07-07  12:52   경기  화성시    NaN                     NaN
# 292  2021-07-07  12:55   경기  화성시    NaN                     NaN
# 293  2021-07-07  13:06   경기  화성시    NaN                     NaN
# 294  2021-07-07  13:22   경기  화성시    NaN                     NaN
# 295  2021-07-07  13:42   경기  화성시  동탄반석로                     NaN
# 296  2021-07-07  13:55   경기  화성시  동탄중앙로       경기도 화성시 반송동 264-3
# 297  2021-07-07  14:17   경기  화성시  동탄원천로         경기도 화성시 석우동 110
# 298  2021-07-07  14:27   경기  화성시    여울로         경기도 화성시 능동 1175
# 299  2021-07-07  14:36   경기  화성시  동탄공원로       경기도 화성시 반송동 244-1
#
#                           종점    기온     습도  재비산먼지 평균농도  오염범례
# 0           서울특별시 구로구 온수동 56  28.0   57.0        27.0  매우좋음
# 1        서울특별시 구로구 개봉동 243-2  28.0   58.0        18.0  매우좋음
# 2         서울특별시 구로구 고척동 1-15  29.0   54.0        33.0  매우좋음
# 3         서울특별시 구로구 오류동 6-41  29.0   54.0        19.0  매우좋음
# 4                        NaN  29.0   56.0        23.0  매우좋음
# 5                        NaN  31.0    NaN        49.0  매우좋음
# 6                        NaN  31.0   50.0        22.0  매우좋음
# 7                        NaN  31.0   49.0        21.0  매우좋음
# 8                        NaN  31.0   48.0        29.0  매우좋음
# 9                        NaN  32.0    NaN        15.0  매우좋음
# 10                       NaN  31.0   48.0        22.0  매우좋음
# 11                       NaN  32.0   47.0        13.0  매우좋음
# 12                       NaN  32.0   47.0        16.0  매우좋음
# 13      서울특별시 구로구 구로동 179-13  32.0   46.0        10.0  매우좋음
# 14         서울특별시 구로구 구로동 772  32.0   47.0        27.0  매우좋음
# 15                       NaN  31.0   47.0        95.0    좋음
# 16                       NaN  31.0   48.0       152.0    나쁨
# 18                       NaN  28.0   87.0        31.0  매우좋음
# 19                       NaN  29.0   82.0        30.0  매우좋음
# 20                       NaN  30.0   75.0        25.0  매우좋음
# 21                       NaN  29.0   78.0        31.0  매우좋음
# 22                       NaN  29.0   77.0        23.0  매우좋음
# 23                       NaN   NaN   73.0        34.0  매우좋음
# 24                       NaN  29.0   77.0        29.0  매우좋음
# 25        인천광역시 부평구 산곡동 97-1  30.0   77.0        25.0  매우좋음
# 26      인천광역시 부평구 부평동 38-130  30.0   78.0        26.0  매우좋음
# 27       인천광역시 부평구 갈산동 120-7  30.0   71.0        42.0  매우좋음
# 28         인천광역시 부평구 삼산동 452  31.0   66.0        22.0  매우좋음
# 29         인천광역시 부평구 청천동 388  30.0   70.0        20.0  매우좋음
# 30       서울특별시 금천구 독산동 995-5  29.0   78.0         2.0  매우좋음
# ..                       ...   ...    ...         ...   ...
# 270                      NaN  30.0   85.0        15.0  매우좋음
# 271          경기도 부천시 삼정동 335  29.0   87.0        12.0  매우좋음
# 272           경기도 부천시 상동 497  29.0   88.0        13.0  매우좋음
# 273         경기도 부천시 삼정동 1-23  29.0   88.0        14.0  매우좋음
# 274        경기도 부천시 삼정동 20-10  30.0   85.0       195.0    나쁨
# 275           경기도 부천시 내동 395  30.0   86.0       135.0    보통
# 276          경기도 부천시 심곡동 500  30.0   85.0        19.0  매우좋음
# 277        경기도 부천시 괴안동 206-5  31.0    NaN        34.0  매우좋음
# 278           경기도 부천시 상동 627  30.0   87.0        17.0  매우좋음
# 279    경기도 화성시 향남읍 제암리 197-1  27.0  100.0       200.0    나쁨
# 280     경기도 화성시 향남읍 하길리 1552  27.0  100.0        30.0  매우좋음
# 281    경기도 화성시 향남읍 행정리 526-4  26.0  100.0        35.0  매우좋음
# 282    경기도 화성시 향남읍 행정리 583-1  26.0    NaN        49.0  매우좋음
# 283      경기도 화성시 향남읍 행정리 552  27.0  100.0        54.0    좋음
# 284    경기도 화성시 향남읍 행정리 553-1  27.0  100.0        50.0  매우좋음
# 285     경기도 화성시 봉담읍 유리 329-1  27.0    NaN        99.0    좋음
# 286     경기도 화성시 봉담읍 분천리 66-3  27.0  100.0        61.0    좋음
# 287  경기도 화성시 봉담읍 와우리 156-106  27.0  100.0       135.0    보통
# 288        경기도 화성시 반월동 118-4  27.0  100.0       127.0    보통
# 289          경기도 화성시 석우동 114  27.0  100.0        18.0  매우좋음
# 290        경기도 화성시 반송동 243-4  27.0  100.0        21.0  매우좋음
# 291        경기도 화성시 반송동 290-2  27.0  100.0        19.0  매우좋음
# 292       경기도 화성시 병점동 501-12  27.0  100.0        15.0  매우좋음
# 293        경기도 화성시 진안동 600-1  28.0  100.0       187.0    나쁨
# 294        경기도 화성시 반송동 233-3  28.0  100.0        27.0  매우좋음
# 295        경기도 화성시 반송동 289-2  29.0   98.0        18.0  매우좋음
# 296        경기도 화성시 영천동 164-4  29.0   96.0        28.0  매우좋음
# 297          경기도 화성시 능동 1176  29.0   96.0        10.0  매우좋음
# 298          경기도 화성시 능동 1245  29.0   94.0        86.0    좋음
# 299          경기도 화성시 반송동 110  29.0   94.0        15.0  매우좋음
#
# [297 rows x 11 columns]

# %% [markdown]
# #### 2.3
# 데이터를 살펴보던 타민은 아래와 같이 데이터를 조작해서 다음 분석 단계로 넘어가려 합니다. <p>아래 순서와 조건에 맞게 데이터를 수정해보세요(inplace=True).
#
#     1) '도로명', '시작점', '종점' 데이터를 제외하고 분석할거야 (컬럼 기준 tresh 사용하기)
#     2) '측정 시간', '지역', '지역명'의 공백은 바로 위 데이터로 대체할래 (hint: method='ffill')
#     3) '측정 일자'와 '지역명', '재비산먼지'가 중복되는 데이터는 가장 첫번째 케이스를 제외하고 제외해야지 (hint:drop_duplicates, keep='First')
#     4) '기온', '습도'의 결측값은 각 열의 평균값으로 채울래
#     5) '오염범례'의 결측값은 최빈값으로 대체하자(hint: value_counts())

# %%
data.dropna(axis = 1, thresh = 250, inplace = True)
data[['측정시간','지역','지역명']] = data[['측정시간','지역','지역명']].fillna(method = 'ffill')
data1 = data.drop_duplicates(subset = ['측정일자','지역명','재비산먼지 평균농도'], keep = 'first')
data1[['기온','습도']] = data1[['기온','습도']].replace(to_replace = np.nan, value = data1[['기온','습도']].mean())
print(data1['오염범례'].value_counts())
data1['오염범례'].fillna('매우좋음', inplace = True)
data1
# Out:
# 매우좋음    178
# 좋음       40
# 보통        9
# 나쁨        5
# 매우나쁨      2
# Name: 오염범례, dtype: int64
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#            측정일자   측정시간  지역  지역명         기온          습도  재비산먼지 평균농도  오염범례
# 0    2021-07-01   9:44  서울  구로구  28.000000   57.000000        27.0  매우좋음
# 1    2021-07-01  10:04  서울  구로구  28.000000   58.000000        18.0  매우좋음
# 2    2021-07-01  10:28  서울  구로구  29.000000   54.000000        33.0  매우좋음
# 3    2021-07-01  10:35  서울  구로구  29.000000   54.000000        19.0  매우좋음
# 4    2021-07-01  11:04  서울  구로구  29.000000   56.000000        23.0  매우좋음
# 5    2021-07-01  11:49  서울  구로구  31.000000   75.831858        49.0  매우좋음
# 6    2021-07-01  11:57  서울  구로구  31.000000   50.000000        22.0  매우좋음
# 7    2021-07-01  12:09  서울  구로구  31.000000   49.000000        21.0  매우좋음
# 8    2021-07-01  12:23  서울  구로구  31.000000   48.000000        29.0  매우좋음
# 9    2021-07-01  12:30  서울  구로구  32.000000   75.831858        15.0  매우좋음
# 11   2021-07-01  12:51  서울  구로구  32.000000   47.000000        13.0  매우좋음
# 12   2021-07-01  13:02  서울  구로구  32.000000   47.000000        16.0  매우좋음
# 13   2021-07-01  13:15  서울  구로구  32.000000   46.000000        10.0  매우좋음
# 15   2021-07-01  13:37  서울  구로구  31.000000   47.000000        95.0    좋음
# 16   2021-07-01  13:49  서울  구로구  31.000000   48.000000       152.0    나쁨
# 17   2021-07-01  13:49  서울  구로구  32.000000   46.000000         NaN  매우좋음
# 18   2021-07-01  13:49  서울  구로구  28.000000   87.000000        31.0  매우좋음
# 19   2021-07-01  13:49  서울  구로구  29.000000   82.000000        30.0  매우좋음
# 20   2021-07-01  10:25  인천  부평구  30.000000   75.000000        25.0  매우좋음
# 21   2021-07-01  10:45  인천  부평구  29.000000   78.000000        31.0  매우좋음
# 22   2021-07-01  10:49  인천  부평구  29.000000   77.000000        23.0  매우좋음
# 23   2021-07-01  10:55  인천  부평구  28.150407   73.000000        34.0  매우좋음
# 24   2021-07-01  11:05  인천  부평구  29.000000   77.000000        29.0  매우좋음
# 26   2021-07-01  11:20  인천  부평구  30.000000   78.000000        26.0  매우좋음
# 27   2021-07-01  11:33  인천  부평구  30.000000   71.000000        42.0  매우좋음
# 28   2021-07-01  11:33  인천  부평구  31.000000   66.000000        22.0  매우좋음
# 29   2021-07-01  12:03  인천  부평구  30.000000   70.000000        20.0  매우좋음
# 30   2021-07-01  10:01  서울  금천구  29.000000   78.000000         2.0  매우좋음
# 31   2021-07-01  10:08  서울  금천구  29.000000   78.000000         7.0  매우좋음
# 32   2021-07-01  10:20  서울  금천구  29.000000   80.000000        29.0  매우좋음
# ..          ...    ...  ..  ...        ...         ...         ...   ...
# 266  2021-07-07  10:11  경기  부천시  29.000000   89.000000        29.0  매우좋음
# 267  2021-07-07  10:20  경기  부천시  29.000000   89.000000        12.0  매우좋음
# 268  2021-07-07  10:53  경기  부천시  29.000000   90.000000        21.0  매우좋음
# 269  2021-07-07  10:58  경기  부천시  30.000000   87.000000        13.0  매우좋음
# 270  2021-07-07  11:26  경기  부천시  30.000000   85.000000        15.0  매우좋음
# 274  2021-07-07  12:25  경기  부천시  30.000000   85.000000       195.0    나쁨
# 275  2021-07-07  12:37  경기  부천시  30.000000   86.000000       135.0    보통
# 276  2021-07-07  12:45  경기  부천시  30.000000   85.000000        19.0  매우좋음
# 277  2021-07-07  14:07  경기  부천시  31.000000   75.831858        34.0  매우좋음
# 278  2021-07-07  14:39  경기  부천시  30.000000   87.000000        17.0  매우좋음
# 279  2021-07-07  10:37  경기  화성시  27.000000  100.000000       200.0    나쁨
# 280  2021-07-07  10:45  경기  화성시  27.000000  100.000000        30.0  매우좋음
# 281  2021-07-07  11:01  경기  화성시  26.000000  100.000000        35.0  매우좋음
# 282  2021-07-07  11:10  경기  화성시  26.000000   75.831858        49.0  매우좋음
# 283  2021-07-07  11:15  경기  화성시  27.000000  100.000000        54.0    좋음
# 284  2021-07-07  11:20  경기  화성시  27.000000  100.000000        50.0  매우좋음
# 285  2021-07-07  11:36  경기  화성시  27.000000   75.831858        99.0    좋음
# 286  2021-07-07  11:55  경기  화성시  27.000000  100.000000        61.0    좋음
# 287  2021-07-07  12:10  경기  화성시  27.000000  100.000000       135.0    보통
# 288  2021-07-07  12:17  경기  화성시  27.000000  100.000000       127.0    보통
# 289  2021-07-07  12:42  경기  화성시  27.000000  100.000000        18.0  매우좋음
# 290  2021-07-07  12:47  경기  화성시  27.000000  100.000000        21.0  매우좋음
# 291  2021-07-07  12:52  경기  화성시  27.000000  100.000000        19.0  매우좋음
# 292  2021-07-07  12:55  경기  화성시  27.000000  100.000000        15.0  매우좋음
# 293  2021-07-07  13:06  경기  화성시  28.000000  100.000000       187.0    나쁨
# 294  2021-07-07  13:22  경기  화성시  28.000000  100.000000        27.0  매우좋음
# 296  2021-07-07  13:55  경기  화성시  29.000000   96.000000        28.0  매우좋음
# 297  2021-07-07  14:17  경기  화성시  29.000000   96.000000        10.0  매우좋음
# 298  2021-07-07  14:27  경기  화성시  29.000000   94.000000        86.0    좋음
# 300         NaN  14:36  경기  화성시  28.150407   75.831858         NaN  매우좋음
#
# [257 rows x 8 columns]

# %% [markdown]
# #### 2.4
# 타민처럼 데이터를 처리했을 때 생길 수 있는 문제점은 무엇일까요? 여러분이라면 이 데이터를 어떻게 처리할 것인가요? <p>
#     자유롭게 생각해봅시다:)

# %% [markdown]
# 결측값을 자신이 원하는데로 채워서, 모델의 예측력이 떨어질수도 있다.
# 날짜, 시간, 지역, 지역명 등 분류 가능한 변수들의 결측값을 먼저 처리한다.
# 그 다음, 날짜별, 시간별, 지역, 지역명을 따로 나누어 기온, 습도 등의 수치 값을 갖는 변수들의 각 평균이나 중앙값으로 결측값을 대체한다.

# %% [markdown]
# ### 3. 불균형 데이터
# 1번 문제에서 만든 embark_town_labels 열을 추가한 titanic 데이터프레임을 사용하여,  <p>
# X는 pclass, embark_town_labels, y는 survived로 X와 y값을 설정하세요.  <p>
# 위 X,y에 대해 over sampling 기법 중 하나를 선택하여 전처리를 진행하고 어떻게 데이터가 변화하였는지 살펴보세요.  <p>
# (hint: shape, value_counts 등을 통해 샘플링 전후 데이터 개수의 변화를 알 수 있습니다.)<p>

# %%
from imblearn.over_sampling import *

# %%
X = titanic[['pclass','embark_town_labels']]
y = titanic['survived']
print('the shape of X:', X.shape)
print('the shape of y:', y.shape)
print('counts of label "1":', sum(y == 1))
print('counts of label "0":', sum(y == 0))
# Out:
# the shape of X: (891, 2)
# the shape of y: (891,)
# counts of label "1": 342
# counts of label "0": 549

# %%
X_resampled, y_resampled = ADASYN(random_state = 0).fit_resample(X, y)
print('the shape of X_resampled:', X_resampled.shape)
print('the shape of y_resampled:', y_resampled.shape)
print('counts of label "1":', sum(y_resampled == 1))
print('counts of label "0":', sum(y_resampled == 0))
# Out:
# the shape of X_resampled: (1164, 2)
# the shape of y_resampled: (1164,)
# counts of label "1": 615
# counts of label "0": 549

# %% [markdown]
# ### 4. Feature Scaling
# 학구열로 불타오르는 타민이는 정규 세션에서 배운 Feature Scaling 내용을 스스로 공부해보려고 한다.<p>
# 최근 영화에 관심에 생긴 타민이는 네이버 영화와 왓챠를 자주 이용한다.<p>
# 영화 평점에 굉장히 민감한 타민이는 최근 유행하는 영화 50편의 평점 데이터를 네이버와 왓챠피디아에서 가져왔고, <p>
# 이를 통해 두 영화 평점 사이트의 데이터를 비교해보고자 한다.<p>
# 고민에 빠진 타민이를 도와주자!

# %%
from sklearn.preprocessing import MinMaxScaler

naver_data = pd.read_csv('naver_movie_rating.csv')
watcha_data = pd.read_csv('watcha_movie_rating.csv')

# 완성되지 않은 부분을 채우세요!

# naver_data에서 movie_rating 컬럼만 추출하여 1차원 numpy array로 변환해준다.
naver_rating = naver_data['movie_rating'].values.reshape(-1,1)

# watcha_data에서 movie_rating 컬럼만 추출하여 1차원 numpy array로 변환해준다.
watcha_rating = watcha_data['movie_rating'].values.reshape(-1,1)

# %% [markdown]
# <p style="line-height:200%">네이버에서는 영화 평점을 <b>최소 0점부터 최대 10점까지</b> 부여할 수 있고, 왓챠에서는 영화 평점을 <b>최소 0점부터 최대 5점까지</b> 부여할 수 있다. 즉, 네이버와 왓챠의 평점은 <b>각각 10점, 5점이 만점</b>이고, <b>최저점으로 0점</b>이 존재할 수 있다.</p>
# <br>
# <p style="line-height:200%">이를 고려하여 각 사이트의 평점 데이터를 <b>0부터 1까지의 범위</b>로 스케일링한 결과를 구해보자.</p>
# <br>
# <p style="line-height:200%"><b>※ MinMaxScaler 사용</b></p>

# %%
# 완성되지 않은 부분을 채우세요!

## 미완성 부분 ##

naver_rating1 = np.append(naver_rating, np.array([[0],[10]]),axis = 0)
scaler = MinMaxScaler()
scaler.fit(naver_rating1)
naver_rating_scaled = scaler.transform(naver_rating1)
naver_rating_scaled = np.delete(naver_rating_scaled, [50,51], axis = 0) 

print('스케일링 된 네이버 영화 평점 데이터')
print('최저 평점: ', np.round(naver_rating_scaled.min(),2))
print('최고 평점: ', np.round(naver_rating_scaled.max(),2))
print('평균 평점: ', np.round(naver_rating_scaled.mean(),2))
print('평점 분산: ', np.round(naver_rating_scaled.var(),2))
# Out:
# 스케일링 된 네이버 영화 평점 데이터
# 최저 평점:  0.57
# 최고 평점:  0.93
# 평균 평점:  0.82
# 평점 분산:  0.01

# %% [markdown]
# <p style="line-height:200%"><b>아래의 결과처럼 나오도록 한다.</b></p>
# <br>
# 스케일링 된 네이버 영화 평점 데이터<br>
# 최저 평점:  0.57<br>
# 최고 평점:  0.93<br>
# 평균 평점:  0.82<br>
# 평점 분산:  0.01<br>

# %%
# 완성되지 않은 부분을 채우세요!

## 미완성 부분 ##

watcha_rating1 = np.append(watcha_rating, np.array([[0],[5]]),axis = 0)
scaler = MinMaxScaler()
scaler.fit(watcha_rating1)
watcha_rating_scaled = scaler.transform(watcha_rating1)
watcha_rating_scaled = np.delete(watcha_rating_scaled, [50,51], axis = 0) 

print('스케일링 된 왓챠 영화 평점 데이터')
print('최저 평점: ', np.round(watcha_rating_scaled.min(),2))
print('최고 평점: ', np.round(watcha_rating_scaled.max(),2))
print('평균 평점: ', np.round(watcha_rating_scaled.mean(),2))
print('평점 분산: ', np.round(watcha_rating_scaled.var(),2))
# Out:
# 스케일링 된 왓챠 영화 평점 데이터
# 최저 평점:  0.5
# 최고 평점:  0.84
# 평균 평점:  0.71
# 평점 분산:  0.01

# %% [markdown]
# <p style="line-height:200%"><b>아래의 결과처럼 나오도록 한다.</b></p>
# <br>
# 스케일링 된 왓챠 영화 평점 데이터<br>
# 최저 평점:  0.5<br>
# 최고 평점:  0.84<br>
# 평균 평점:  0.71<br>
# 평점 분산:  0.01<br>

# %% [markdown]
# <p style="line-height:200%">만약 네이버와 왓챠 평점의 <b>만점이 모두 10점</b>이고, 조사한 왓챠 평점 데이터가 5점 만점이 아닌 <b>10점 만점일 때의 데이터</b>라고 가정해 보자.</p>
# <br>
# <p>이 때 왓챠 사이트의 평점 데이터를 <b>0부터 1까지의 범위</b>로 스케일링한 결과를 각각 구해보자.</p>

# %%
# 완성되지 않은 부분을 채우세요!

## 미완성 부분 ##

watcha_rating1 = np.append(watcha_rating, np.array([[0],[10]]),axis = 0)
scaler = MinMaxScaler()
scaler.fit(watcha_rating1)
watcha_rating_scaled = scaler.transform(watcha_rating1)
watcha_rating_scaled = np.delete(watcha_rating_scaled, [50,51], axis = 0) 

print('스케일링 된 10점 만점의 왓챠 영화 평점 데이터')
print('최저 평점: ', np.round(watcha_rating_scaled.min(),2))
print('최고 평점: ', np.round(watcha_rating_scaled.max(),2))
print('평균 평점: ', np.round(watcha_rating_scaled.mean(),2))
print('평점 분산: ', np.round(watcha_rating_scaled.var(),2))
# Out:
# 스케일링 된 10점 만점의 왓챠 영화 평점 데이터
# 최저 평점:  0.25
# 최고 평점:  0.42
# 평균 평점:  0.36
# 평점 분산:  0.0
